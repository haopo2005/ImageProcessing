# %%
# %matplotlib inline
import cv2
import glob
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
from skimage import feature
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))
# Out:
# <style>.container { width:60% !important; }</style>

# %%
def canny(imx):
    import cv2
    ima = cv2.imread(imx)
    grayi = cv2.cvtColor(ima, cv2.COLOR_BGR2GRAY)
    edges1 = feature.canny(grayi)
    edges2 = feature.canny(grayi, sigma=3)
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 11),sharex=True, sharey=False)
    print(imx.split("/")[9])
    ax1.imshow(edges1, cmap=plt.cm.gray)
    ax1.axis('off')
    ax1.set_title( 'Canny filter, $\sigma=1$', fontsize=20)
    ax2.imshow(edges2, cmap=plt.cm.gray)
    ax2.axis('off')
    ax2.set_title('Canny filter, $\sigma=3$', fontsize=20)
    #fig.tight_layout()
    plt.show()

# %%
for f in (glob.glob("/Users/rjosyula/Documents/GitHub/BPC/SEQ/Images/Trial/*")):
    canny(f)
# Out:
# Demosaic_Image_56.bmp
# Demosaic_Image_55.bmp
# Sobel_Image_55.tiff
# Sobel_Image_56.tiff
# Raw_Image_56.bmp
# Raw_Image_55.bmp

# %%
cd /Users/rjosyula/Documents/GitHub/BPC/SEQ/SampleImages/
# Out:
# /Users/rjosyula/Documents/GitHub/BPC/SEQ/sampleImages

# %%
import scipy
import numpy as np
from matplotlib.pyplot import *
import matplotlib.image as mpimg
data = np.load('sLeft3.npy')
imsave("1.png",data)

# %%
testPTS = [[5,190],[53,53],[99,5]]
len(testPTS)
# Out:
# 3
